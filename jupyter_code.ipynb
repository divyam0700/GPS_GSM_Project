# %%
import time
from time import sleep

###'''Run this file in your shell, the aim for this script is to try and allow you to
###    send, read and delete messages from python, after playing around with this for a while i have
###    realised that the most importain thing is good signal strength at the modem. For a full list of
###    fuctions that a GSM modem is capable of google Haynes AT+ commands
###    I have put the sleep function into many of the functions found within this script as it give the modem time
###    to receive all the messages from the Mobile Network Operators servers'''

x = input("Fall detection: ")     # Digitalwrite "low" === "F" & Digitalwrite "high" === "T" 
sleep(2)
print("\n","*"*100)
print("***** Welcome to the virtual serial monitor/ lcd display *****")
sleep(3)

if x == "F":
    print("\n> No fall detected.")
    
elif x == "T":
    print("> Fall detected.")
    sleep(2)  
    print("> Tracking....")
    sleep(2)
    print("> GPS Initializing...")
    sleep(2)
    print("> GPS Range found.")
    print("\n","*"*100)
    sleep(2)
    print("***** System is ready *****")
    sleep(2)
    temp = int(input("\nSerial Monitor value of GPS:"))
    sleep(2)
   

while temp > 0:
    print("\n > Reading the encoder value of gps.")
    sleep(2)
    print(" > Track the Object.")
    temp = 0
    break;

    
def gsm_module(): 
    print("\n","*"*100)
    sleep(2)
    print("---> Finding module...")
    sleep(2)
    print("---> Module connected.")
    sleep(2)
    print("---> Disabling ECHO")        # Using "boolean echo_flag=1;" and a while loop to disable the useless Echo.
    sleep(2)
    # getting the info. like "ATE0 no." and "AT+CPIN? no."
    print("*** Network found. ***")
    print("\n","*"*100)
    sleep(2)
    return;
if x == "T":
    gsm_module()
    
# Commiting the mssg using this void loop:

# void init_sms()
# {
#   Serial.println("AT+CMGF=1");
#   delay(400);
#   Serial.println("AT+CMGS=\"9876543210\"");           // use your 10 digit cell no. here
#   delay(400);
# }
    
    
def lcd_final_status():
    print("\nMessage Sent.\n")
    sleep(2)
    print("****** System Updated Ready ******")
    print("X"*120,"\n")
    return;
if x == "T":
    lcd_final_status()
      
lat = "latitude coordinates"        # generating latitude with "gps.location.lat()"
long = "longitude coordinates"      # generating longitude with "gps.location.lng()"


def tracking():
    print("\n","*"*100)
    print("Message format is:")
    sleep(2)
    print("\nPerson's current location is: https://www.google.com.bd/maps/@latitude-coordinate,longitude-coordinate,16.58z")
    print("\nlatitude:", lat)        # generating latitude with "gps.location.lat()"
    print("longitude:", long)      # generating longitude with "gps.location.lng()"
    sleep(2)
    print("*"*100)
    return;
if x == "T":
    tracking()    
    
    
# *******  FORMAT of the MESSAGE is: ******* 

# https://www.google.com.bd/maps/@latitude-coordinate,longitude-coordinate,16.58z
# latitude: "latitude coordinates"
# longitude: "longitude coordinates"
# Out:
# Fall detection: T
#
#  ****************************************************************************************************
# ***** Welcome to the virtual serial monitor/ lcd display *****
# > Fall detected.
# > Tracking....
# > GPS Initializing...
# > GPS Range found.
#
#  ****************************************************************************************************
# ***** System is ready *****
#
# Serial Monitor value of GPS:2
#
#  > Reading the encoder value of gps.
#  > Track the Object.
#
#  ****************************************************************************************************
# ---> Finding module...
# ---> Module connected.
# ---> Disabling ECHO
# *** Network found. ***
#
#  ****************************************************************************************************
#
# Message Sent.
#
# ****** System Updated Ready ******
#
# ...
